# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from urllib.request import Request, urlopen
import json

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

data = urlopen(Request(url)).read()
json_data = json.loads(data)
df_full = pd.DataFrame(json_data["Data"])
df_full.head()
# Out:
#                  42   300  365      404       433      611      808  888  \
# Algorithm    Scrypt   N/A  X11   Scrypt       N/A  SHA-256  SHA-256  N/A
# BlockNumber  197923     0  NaN    50759  10821438      NaN        0    0
# BlockReward       0     0  NaN  15.6382         2      NaN        0    0
# BlockTime         0     0  NaN       60         0      NaN        0   88
# BuiltOn         N/A  7605  N/A      N/A      7605      N/A      N/A  N/A
#
#                 1337 2015  ...   DHT       XAYA   CHI   CEL   ROT YAMV2 YAMV1  \
# Algorithm        X13  X11  ...   N/A  NeoScrypt   N/A   N/A   N/A   N/A   N/A
# BlockNumber  2761747  NaN  ...     0        NaN     0     0     0     0     0
# BlockReward  83.0292  NaN  ...     0        NaN     0     0     0     0     0
# BlockTime         60  NaN  ...     0        NaN     0     0     0     0     0
# BuiltOn          N/A  N/A  ...  7605        N/A  7605  7605  7605  7605  7605
#
#               YAM SHROOM  JACS
# Algorithm     N/A    N/A   N/A
# BlockNumber     0      0     0
# BlockReward     0      0     0
# BlockTime       0      0     0
# BuiltOn      7605   7605  7605
#
# [5 rows x 5367 columns]

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
df_transpose = df_full.T
df_transpose.head()
# Out:
#     Algorithm BlockNumber BlockReward BlockTime BuiltOn   CoinName  \
# 42     Scrypt      197923           0         0     N/A    42 Coin
# 300       N/A           0           0         0    7605  300 token
# 365       X11         NaN         NaN       NaN     N/A    365Coin
# 404    Scrypt       50759     15.6382        60     N/A    404Coin
# 433       N/A    10821438           2         0    7605  433 Token
#
#     ContentCreatedOn DecimalPlaces         FullName FullyPremined  ...  \
# 42        1427211129             0     42 Coin (42)             0  ...
# 300       1517935016            18  300 token (300)             0  ...
# 365       1480032918             0    365Coin (365)             0  ...
# 404       1466100361             0    404Coin (404)             0  ...
# 433       1541597321            18  433 Token (433)             0  ...
#
#                                                 Rating  \
# 42   {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 300  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 365  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 404  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 433  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
#
#                            SmartContractAddress SortOrder Sponsored Symbol  \
# 42                                          N/A        34     False     42
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557      2212     False    300
# 365                                         N/A       916     False    365
# 404                                         N/A       602     False    404
# 433  0x738505a5f31bf72e0b70298bca81150eb1b7c751      3505     False    433
#
#                                               Taxonomy TotalCoinSupply  \
# 42   {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...              42
# 300  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...             300
# 365  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      2300000000
# 404  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...       532000000
# 433  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      1000000000
#
#     TotalCoinsFreeFloat TotalCoinsMined                  Url
# 42                  N/A              42   /coins/42/overview
# 300                 N/A             300  /coins/300/overview
# 365                 N/A             NaN  /coins/365/overview
# 404                 N/A     1.37995e+06  /coins/404/overview
# 433                 N/A     1.12518e+08  /coins/433/overview
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'

df = df_transpose[["CoinName", "Algorithm", "IsTrading", "ProofType", "TotalCoinsMined", "TotalCoinSupply"]]
df.head()
# Out:
#       CoinName Algorithm IsTrading ProofType TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt      True   PoW/PoS              42              42
# 300  300 token       N/A      True       N/A             300             300
# 365    365Coin       X11      True   PoW/PoS             NaN      2300000000
# 404    404Coin    Scrypt      True   PoW/PoS     1.37995e+06       532000000
# 433  433 Token       N/A     False       N/A     1.12518e+08      1000000000

# %%
# Keep only cryptocurrencies that are trading

df = df.loc[df.IsTrading != False]
df.head()
# Out:
#       CoinName Algorithm IsTrading ProofType TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt      True   PoW/PoS              42              42
# 300  300 token       N/A      True       N/A             300             300
# 365    365Coin       X11      True   PoW/PoS             NaN      2300000000
# 404    404Coin    Scrypt      True   PoW/PoS     1.37995e+06       532000000
# 611  SixEleven   SHA-256      True       PoW             NaN          611000

# %%
# Keep only cryptocurrencies with a working algorithm

df = df.loc[df.Algorithm != "N/A"]
df.head()
# Out:
#       CoinName Algorithm IsTrading ProofType TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt      True   PoW/PoS              42              42
# 365    365Coin       X11      True   PoW/PoS             NaN      2300000000
# 404    404Coin    Scrypt      True   PoW/PoS     1.37995e+06       532000000
# 611  SixEleven   SHA-256      True       PoW             NaN          611000
# 808        808   SHA-256      True   PoW/PoS               0               0

# %%
# Remove the 'IsTrading' column

df = df.drop(columns = "IsTrading")
df.head()
# Out:
#       CoinName Algorithm ProofType TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS              42              42
# 365    365Coin       X11   PoW/PoS             NaN      2300000000
# 404    404Coin    Scrypt   PoW/PoS     1.37995e+06       532000000
# 611  SixEleven   SHA-256       PoW             NaN          611000
# 808        808   SHA-256   PoW/PoS               0               0

# %%
# Remove rows with at least 1 null value

df = df.dropna()
df.isnull().sum()
# Out:
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# TotalCoinSupply    0
# dtype: int64

# %%
# Remove rows with cryptocurrencies having no coins mined

df = df.loc[df.TotalCoinsMined != 0]
df.head()
# Out:
#          CoinName Algorithm ProofType TotalCoinsMined TotalCoinSupply
# 42        42 Coin    Scrypt   PoW/PoS              42              42
# 404       404Coin    Scrypt   PoW/PoS     1.37995e+06       532000000
# 1337    EliteCoin       X13   PoW/PoS     2.94826e+10    314159265359
# BTCD  BitcoinDark   SHA-256   PoW/PoS         1288862        22000000
# XPY       PayCoin   SHA-256       PoS     1.19953e+07        12500000

# %%
# Drop rows where there are 'N/A' text values

for i in df.columns:
    print (df[df[i] == "N/A"])

# Dropping rows where there are "N/A" text values in ProofType
df = df.loc[df["ProofType"].str.contains("N/A") == False]

# Dropping rows where there are "N/A" text values in TotalCoinsSupply
df = df.loc[df["TotalCoinSupply"].str.contains("N/A") == False]
# Out:
# Empty DataFrame
# Columns: [CoinName, Algorithm, ProofType, TotalCoinsMined, TotalCoinSupply]
# Index: []
# Empty DataFrame
# Columns: [CoinName, Algorithm, ProofType, TotalCoinsMined, TotalCoinSupply]
# Index: []
#                           CoinName      Algorithm ProofType TotalCoinsMined  \
# XPD                    PetroDollar       SHA-256D       N/A        63993275
# CREVA                   Creva Coin            X11       N/A        36390750
# UNC                         UnCoin            X11       N/A         8388608
# BCY                    BitCrystals   Counterparty       N/A       100000000
# SCOT                      Scotcoin   Counterparty       N/A      1000000000
# PASC                   Pascal Coin         Pascal       N/A        32607325
# NETKO                        Netko          Blake       N/A        10969740
# WGR                         Wagerr            PoS       N/A       200000000
# GRWI         Growers International           DPoS       N/A     1.22049e+06
# AURS                        Aureus         Scrypt       N/A        21000000
# BPL                      BlockPool           DPoS       N/A     2.52764e+07
# XCPO                        Copico            PoS       N/A     3.33061e+07
# Q2C                      QubitCoin          QuBit       N/A     2.51167e+08
# TKY                   THEKEY Token      NeoScrypt       N/A      9795844687
# DOR                         Dorado         Ethash       N/A        83720601
# LGR                      Logarithm         Ethash       N/A        66666670
# ZIP                         Zipper           DPoS       N/A    100000000000
# ROBET                        RoBet         Keccak       N/A       102102102
# ABBC                     ABBC Coin            X13       N/A     1.00328e+09
# URX                       URANIUMX        Argon2d       N/A         52901.1
# LABX                    Stakinglab          Quark       N/A          417744
# AWC             Atomic Wallet Coin  ERC20 + BEP-2       N/A       100000000
# MONT                 Monarch Token         Ethash       N/A      1000000000
# XPC               eXPerience Chain        SHA-256       N/A     1.16316e+11
# BUX                        Buxcoin         Scrypt       N/A     4.50059e+08
# XSPC           SpectreSecurityCoin            C11       N/A     1.92207e+08
# PHX              Red Pulse Phoenix          NEP-5       N/A       829588687
# MNX                      MinexCoin           Mars       N/A         4805033
# DBC                DeepBrain Chain          NEP-5       N/A      1500000000
# ZOC                         01coin      NeoScrypt       N/A      1.5189e+07
# SCRIV                        SCRIV         Tribus       N/A     8.81569e+07
# OMEGA                        OMEGA            X11       N/A     2.56646e+07
# CRP                       Cranepay    YespowerR16       N/A     7.00073e+07
# AEN                          Aenco         Ethash       N/A      4000000000
# IQC                        IQ.cash      NeoScrypt       N/A     2.00608e+07
# LRG                     Largo Coin        SHA-256       N/A     4.25354e+07
# REDI                          REDi        SHA-256       N/A     10000000000
# ETP                      Metaverse         Ethash       N/A     7.54389e+07
# HPB    High Performance Blockchain           DPoS       N/A       100000000
# NEBL                        Neblio            PoS       N/A     1.69128e+07
# WAXP      Worldwide Asset eXchange           DPoS       N/A      1052205536
# WTC                    Waltonchain         Ethash       N/A        70000000
# RVN                      Ravencoin           X16R       N/A      7.6554e+08
#
#       TotalCoinSupply
# XPD         122107462
# CREVA               0
# UNC      144000000000
# BCY         100000000
# SCOT       1000000000
# PASC              N/A
# NETKO        25534140
# WGR         200000000
# GRWI          1000420
# AURS         21000000
# BPL               N/A
# XCPO        122500000
# Q2C               N/A
# TKY       10000000000
# DOR         510000000
# LGR          66666670
# ZIP      100000000000
# ROBET       102102102
# ABBC       1500000000
# URX            235000
# LABX         21000000
# AWC         100000000
# MONT       1000000000
# XPC      113215461333
# BUX         500000000
# XSPC        500000000
# PHX        1358371250
# MNX          19000000
# DBC       10000000000
# ZOC          66000000
# SCRIV       150000000
# OMEGA        33000000
# CRP          84000000
# AEN        4000000000
# IQC          56900000
# LRG         200000000
# REDI      10000000000
# ETP         100000000
# HPB               N/A
# NEBL              N/A
# WAXP                0
# WTC          70000000
# RVN       21000000000
# Empty DataFrame
# Columns: [CoinName, Algorithm, ProofType, TotalCoinsMined, TotalCoinSupply]
# Index: []
#                                     CoinName         Algorithm      ProofType  \
# CANN                            CannabisCoin               X11            PoW
# CLAM                                   CLAMS               PoS            PoS
# NET                                  NetCoin            Scrypt            PoW
# SDC                               ShadowCash            Scrypt        PoW/PoS
# SWIFT                               BitSwift            Scrypt        PoW/PoS
# XPM                                PrimeCoin          Multiple            PoW
# NBT                                   NuBits           SHA-256            PoS
# START                              StartCoin               X11            PoW
# BAY                                   BitBay               PoS            PoS
# CRAVE                              CraveCoin            Scrypt        PoW/PoS
# GRC                                 GridCoin            Scrypt           DPoR
# XMG                                Coin Magi               M7M  PoW/PoM/PoSII
# CURE                                Curecoin            Scrypt            PoW
# C2                                    Coin.2            Scrypt        PoW/PoS
# BSTY                             GlobalBoost          Yescript            PoW
# SPHR                             Sphere Coin            Scrypt        PoW/PoS
# GP                                GoldPieces               X11        PoW/PoS
# SNRG                                 Synergy               X11        PoW/PoS
# GCR                  Global Currency Reserve               PoS            PoS
# TX                                  Transfer               X11        PoW/PoS
# AMS                           Amsterdam Coin             Quark        PoW/PoS
# XRE                             RevolverCoin            X11Evo            PoW
# MEME                                    Pepe               X11        PoW/PoS
# MOJO                                Mojocoin               PoS            PoS
# DIME                                DimeCoin             Quark            PoW
# CARBON                            Carboncoin            Scrypt            PoW
# NKC                                Nukecoinz            Scrypt            PoW
# MUE                             MonetaryUnit             Quark            PoW
# XDE2                                  XDE II           SHA-256            PoS
# SYNX                               Syndicate               X11        PoW/PoS
# ...                                      ...               ...            ...
# SAGA                                SagaCoin            Scrypt        PoW/PoS
# XTO                                      Tao               X11        PoW/PoS
# KB3                                   B3Coin               X11        PoS/PoD
# UNRC                      UniversalRoyalCoin           SHA-256            PoS
# USCOIN                                USCoin            Scrypt            PoW
# XMO                          Monero Original       CryptoNight            PoW
# WARP                                WarpCoin               PoS            PoS
# BRK                             BreakoutCoin           SHA-256        PoW/PoS
# FLVR                              FlavorCoin           SHA-256        PoW/PoS
# FLY                                  FlyCoin               X13            PoS
# BKC                               Balkancoin       CryptoNight            PoW
# KR                                   Krypton            Scrypt            PoW
# BERN                                BERNcash               X14        PoW/PoS
# APC                                 AlpaCoin           SHA-256            PoW
# ELLI                              ElliotCoin             XEVAN        PoW/PoS
# SSC                                 SelfSell              DPoS           DPoS
# VSYS                               V Systems              SPoS           SPoS
# AC                                 Asia Coin            Scrypt            PoS
# XCP                             CounterParty           SHA-256            PoW
# RISE                                    Rise              DPoS            PoS
# SLS                                    SaluS            Scrypt        PoW/PoS
# HPB              High Performance Blockchain              DPoS            N/A
# PIVX    Private Instant Verified Transaction             Quark        PoW/PoS
# BLOCK                               BlockNet               PoS        PoW/PoS
# NEBL                                  Neblio               PoS            N/A
# UBQ                                     Ubiq  Dagger-Hashimoto            PoW
# STRAT                                Stratis               X13        PoW/PoS
# SHIFT                                  Shift              DPoS           DPoS
# DOGE                                Dogecoin            Scrypt            PoW
# BLK                                BlackCoin            Scrypt            PoS
#
#        TotalCoinsMined TotalCoinSupply
# CANN       2.34153e+08             N/A
# CLAM            -1e-08             N/A
# NET        7.92513e+08             N/A
# SDC        6.72848e+06             N/A
# SWIFT       4.0692e+06             N/A
# XPM           26010068             N/A
# NBT        1.10347e+08             N/A
# START         80320010             N/A
# BAY        1.03455e+09             N/A
# CRAVE      1.52126e+06             N/A
# GRC          412959930             N/A
# XMG        1.14156e+07             N/A
# CURE       2.46647e+07             N/A
# C2          1.3385e+08             N/A
# BSTY       1.87668e+07             N/A
# SPHR           3082940             N/A
# GP         4.09373e+06             N/A
# SNRG       4.81374e+06             N/A
# GCR        1.07008e+08             N/A
# TX         8.29265e+06             N/A
# AMS        1.44045e+08             N/A
# XRE        2.39951e+07             N/A
# MEME       3.83892e+07             N/A
# MOJO       1.11473e+08             N/A
# DIME       5.56017e+11             N/A
# CARBON      1.5392e+10             N/A
# NKC             415768             N/A
# MUE          2.012e+08             N/A
# XDE2            347357             N/A
# SYNX       4.13667e+07             N/A
# ...                ...             ...
# SAGA       1.06683e+07             N/A
# XTO        3.46574e+07             N/A
# KB3        7.87409e+08             N/A
# UNRC          70425621             N/A
# USCOIN     7.64012e+07             N/A
# XMO        1.60132e+07             N/A
# WARP           1095224             N/A
# BRK           18949258             N/A
# FLVR          20898106             N/A
# FLY             210806             N/A
# BKC        1.99526e+08             N/A
# KR             2910710             N/A
# BERN          71234301             N/A
# APC            8825450             N/A
# ELLI       2.74677e+07             N/A
# SSC          390000000             N/A
# VSYS        1938544061             N/A
# AC         2.66396e+09             N/A
# XCP        2.61528e+06             N/A
# RISE       1.60137e+08             N/A
# SLS        1.01424e+06             N/A
# HPB          100000000             N/A
# PIVX      -6.75379e+07             N/A
# BLOCK      7.11535e+06             N/A
# NEBL       1.69128e+07             N/A
# UBQ        3.79867e+07             N/A
# STRAT      9.99672e+07             N/A
# SHIFT         14147348             N/A
# DOGE       1.26384e+11             N/A
# BLK        6.01963e+07             N/A
#
# [90 rows x 5 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df 

crypto_name = df.CoinName
crypto_name.head()
# Out:
# 42          42 Coin
# 404         404Coin
# 1337      EliteCoin
# BTCD    BitcoinDark
# XPY         PayCoin
# Name: CoinName, dtype: object

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm

cluster_df = df.drop(columns = "CoinName")
print(cluster_df.shape)
cluster_df.head()
# Out:
# (539, 4)
#      Algorithm ProofType TotalCoinsMined TotalCoinSupply
# 42      Scrypt   PoW/PoS              42              42
# 404     Scrypt   PoW/PoS     1.37995e+06       532000000
# 1337       X13   PoW/PoS     2.94826e+10    314159265359
# BTCD   SHA-256   PoW/PoS         1288862        22000000
# XPY    SHA-256       PoS     1.19953e+07        12500000

# %%
# Create dummy variables for text features

cluster_df_dummy = pd.get_dummies(cluster_df[["Algorithm", "ProofType"]])
# cluster_df_dummy = pd.get_dummies(cluster_df["ProofType"])
cluster_df_dummy.head()
# Out:
#       Algorithm_1GB AES Pattern Search  Algorithm_536  Algorithm_Argon2d  \
# 42                                   0              0                  0
# 404                                  0              0                  0
# 1337                                 0              0                  0
# BTCD                                 0              0                  0
# XPY                                  0              0                  0
#
#       Algorithm_BLAKE256  Algorithm_BMW512 / Echo512  Algorithm_Blake  \
# 42                     0                           0                0
# 404                    0                           0                0
# 1337                   0                           0                0
# BTCD                   0                           0                0
# XPY                    0                           0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  Algorithm_C31  ...  \
# 42                    0                  0              0              0  ...
# 404                   0                  0              0              0  ...
# 1337                  0                  0              0              0  ...
# BTCD                  0                  0              0              0  ...
# XPY                   0                  0              0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTCD                  1                   0                  0
# XPY                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTCD                   0              0                             0
# XPY                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTCD                         0               0
# XPY                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTCD                               0                   0
# XPY                                0                   0
#
# [5 rows x 110 columns]

# %%
# Standardize data

cluster_df_scaled = StandardScaler().fit_transform(cluster_df_dummy)
cluster_df_scaled[0:5]
# Out:
# array([[-0.04311306, -0.04311306, -0.04311306, -0.06102782, -0.04311306,
#         -0.0748132 , -0.04311306, -0.06102782, -0.06102782, -0.04311306,
#         -0.04311306, -0.04311306, -0.18046343, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.13031167, -0.08646754,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.15720951,
#         -0.04311306, -0.04311306, -0.13031167, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.09676412, -0.06102782, -0.04311306, -0.13749033, -0.13031167,
#         -0.13031167, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.18587346, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.0748132 , -0.19115036, -0.04311306, -0.31622777, -0.04311306,
#         -0.08646754, -0.0748132 , -0.06102782, -0.04311306,  1.45451261,
#         -0.04311306, -0.04311306, -0.06102782, -0.04311306, -0.06102782,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.38949891, -0.04311306, -0.18587346, -0.04311306,
#         -0.08646754, -0.08646754, -0.10609918, -0.04311306, -0.04311306,
#         -0.04311306, -0.14433757, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.06102782, -0.06102782, -0.45960413, -0.04311306,
#         -0.0748132 , -0.04311306, -0.04311306, -0.8660254 , -0.04311306,
#          1.44222051, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.04311306, -0.04311306, -0.04311306, -0.04311306],
#        [-0.04311306, -0.04311306, -0.04311306, -0.06102782, -0.04311306,
#         -0.0748132 , -0.04311306, -0.06102782, -0.06102782, -0.04311306,
#         -0.04311306, -0.04311306, -0.18046343, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.13031167, -0.08646754,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.15720951,
#         -0.04311306, -0.04311306, -0.13031167, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.09676412, -0.06102782, -0.04311306, -0.13749033, -0.13031167,
#         -0.13031167, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.18587346, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.0748132 , -0.19115036, -0.04311306, -0.31622777, -0.04311306,
#         -0.08646754, -0.0748132 , -0.06102782, -0.04311306,  1.45451261,
#         -0.04311306, -0.04311306, -0.06102782, -0.04311306, -0.06102782,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.38949891, -0.04311306, -0.18587346, -0.04311306,
#         -0.08646754, -0.08646754, -0.10609918, -0.04311306, -0.04311306,
#         -0.04311306, -0.14433757, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.06102782, -0.06102782, -0.45960413, -0.04311306,
#         -0.0748132 , -0.04311306, -0.04311306, -0.8660254 , -0.04311306,
#          1.44222051, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.04311306, -0.04311306, -0.04311306, -0.04311306],
#        [-0.04311306, -0.04311306, -0.04311306, -0.06102782, -0.04311306,
#         -0.0748132 , -0.04311306, -0.06102782, -0.06102782, -0.04311306,
#         -0.04311306, -0.04311306, -0.18046343, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.13031167, -0.08646754,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.15720951,
#         -0.04311306, -0.04311306, -0.13031167, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.09676412, -0.06102782, -0.04311306, -0.13749033, -0.13031167,
#         -0.13031167, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.18587346, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.0748132 , -0.19115036, -0.04311306, -0.31622777, -0.04311306,
#         -0.08646754, -0.0748132 , -0.06102782, -0.04311306, -0.68751552,
#         -0.04311306, -0.04311306, -0.06102782, -0.04311306, -0.06102782,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.38949891, -0.04311306,  5.38000413, -0.04311306,
#         -0.08646754, -0.08646754, -0.10609918, -0.04311306, -0.04311306,
#         -0.04311306, -0.14433757, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.06102782, -0.06102782, -0.45960413, -0.04311306,
#         -0.0748132 , -0.04311306, -0.04311306, -0.8660254 , -0.04311306,
#          1.44222051, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.04311306, -0.04311306, -0.04311306, -0.04311306],
#        [-0.04311306, -0.04311306, -0.04311306, -0.06102782, -0.04311306,
#         -0.0748132 , -0.04311306, -0.06102782, -0.06102782, -0.04311306,
#         -0.04311306, -0.04311306, -0.18046343, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.13031167, -0.08646754,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.15720951,
#         -0.04311306, -0.04311306, -0.13031167, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.09676412, -0.06102782, -0.04311306, -0.13749033, -0.13031167,
#         -0.13031167, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.18587346, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.0748132 , -0.19115036, -0.04311306,  3.16227766, -0.04311306,
#         -0.08646754, -0.0748132 , -0.06102782, -0.04311306, -0.68751552,
#         -0.04311306, -0.04311306, -0.06102782, -0.04311306, -0.06102782,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.38949891, -0.04311306, -0.18587346, -0.04311306,
#         -0.08646754, -0.08646754, -0.10609918, -0.04311306, -0.04311306,
#         -0.04311306, -0.14433757, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.06102782, -0.06102782, -0.45960413, -0.04311306,
#         -0.0748132 , -0.04311306, -0.04311306, -0.8660254 , -0.04311306,
#          1.44222051, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.04311306, -0.04311306, -0.04311306, -0.04311306],
#        [-0.04311306, -0.04311306, -0.04311306, -0.06102782, -0.04311306,
#         -0.0748132 , -0.04311306, -0.06102782, -0.06102782, -0.04311306,
#         -0.04311306, -0.04311306, -0.18046343, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.13031167, -0.08646754,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.15720951,
#         -0.04311306, -0.04311306, -0.13031167, -0.04311306, -0.04311306,
#         -0.08646754, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.09676412, -0.06102782, -0.04311306, -0.13749033, -0.13031167,
#         -0.13031167, -0.04311306, -0.04311306, -0.04311306, -0.0748132 ,
#         -0.18587346, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.0748132 , -0.19115036, -0.04311306,  3.16227766, -0.04311306,
#         -0.08646754, -0.0748132 , -0.06102782, -0.04311306, -0.68751552,
#         -0.04311306, -0.04311306, -0.06102782, -0.04311306, -0.06102782,
#         -0.04311306, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.38949891, -0.04311306, -0.18587346, -0.04311306,
#         -0.08646754, -0.08646754, -0.10609918, -0.04311306, -0.04311306,
#         -0.04311306, -0.14433757, -0.04311306, -0.04311306, -0.04311306,
#         -0.04311306, -0.06102782, -0.06102782,  2.1757855 , -0.04311306,
#         -0.0748132 , -0.04311306, -0.04311306, -0.8660254 , -0.04311306,
#         -0.69337525, -0.04311306, -0.04311306, -0.04311306, -0.04311306,
#         -0.06102782, -0.04311306, -0.04311306, -0.04311306, -0.04311306]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components

pca = PCA(n_components=3)

cluster_pca = pca.fit_transform(cluster_df_scaled)

# %%
# Create a DataFrame with the principal components data

df_cluster_pca = pd.DataFrame(data = cluster_pca, 
                              columns=["PC 1", "PC 2", "PC 3"], index = cluster_df.index
                              )
                    
print(cluster_pca.shape)
df_cluster_pca.head()
# Out:
# (539, 3)
#           PC 1      PC 2      PC 3
# 42    0.862548 -0.851033  0.022520
# 404   0.862548 -0.851033  0.022520
# 1337  1.847576 -0.832858  0.119968
# BTCD  0.885688 -0.463606  0.071518
# XPY   0.568357  0.017943  0.049537

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_cluster_pca)
    inertia.append(km.inertia_)


# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model

model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(df_cluster_pca)

# Predict clusters
predictions = model.predict(df_cluster_pca)

# Add the predicted class columns
df_cluster_pca["class"] = model.labels_
df_cluster_pca.head()
# df_cluster_pca.shape

# Create a new DataFrame including predicted clusters and cryptocurrencies features
df_clustered = pd.DataFrame({
    "Algorithm" : cluster_df.Algorithm,
    "ProofType": cluster_df.ProofType,
    "TotalCoinsMined": cluster_df.TotalCoinsMined,
    "TotalCoinSupply": cluster_df.TotalCoinSupply,
    "principal component 1": df_cluster_pca["PC 1"],
    "principal component 2": df_cluster_pca["PC 2"], 
    "principal component 3": df_cluster_pca["PC 3"],
    "CoinName": crypto_name,
    "Class": df_cluster_pca["class"]
    }, index = cluster_df.index
    )

df_clustered.head(20)
# Out:
#      Algorithm ProofType TotalCoinsMined TotalCoinSupply  \
# 42      Scrypt   PoW/PoS              42              42
# 404     Scrypt   PoW/PoS     1.37995e+06       532000000
# 1337       X13   PoW/PoS     2.94826e+10    314159265359
# BTCD   SHA-256   PoW/PoS         1288862        22000000
# XPY    SHA-256       PoS     1.19953e+07        12500000
# PRC     Scrypt       PoW         6268245        21000000
# KOBO       X15   PoW/PoS     2.56004e+07       350000000
# ARG     Scrypt       PoW      1.3833e+07        64000000
# BLU     Scrypt   PoW/PoS       647272555               0
# XMY   Multiple       PoW      1750253250      2000000000
# MOON    Scrypt       PoW              88    384000000000
# ZET    SHA-256       PoW     1.72498e+08       169795588
# SXC     Scrypt       PoW     1.28941e+08       250000000
# QTL     Scrypt       PoW     7.35779e+06       100000000
# ENRG    Scrypt   PoW/PoS     1.24171e+08               0
# QRK      Quark       PoW     2.66419e+08       247000000
# RIC    Groestl       PoW     5.52242e+07        84000000
# DGC     Scrypt       PoW      3.6085e+07        48166000
# BTB     Scrypt   PoW/PoS         47356.6          500000
# CAT     Scrypt       PoW     7.21996e+06       21000000
#
#       principal component 1  principal component 2  principal component 3  \
# 42                 0.862548              -0.851033               0.022520
# 404                0.862548              -0.851033               0.022520
# 1337               1.847576              -0.832858               0.119968
# BTCD               0.885688              -0.463606               0.071518
# XPY                0.568357               0.017943               0.049537
# PRC               -1.270415              -0.050764              -0.040578
# KOBO               1.904570              -0.907186               0.099671
# ARG               -1.270415              -0.050764              -0.040578
# BLU                0.862548              -0.851033               0.022520
# XMY               -1.700987               0.498611              -0.053748
# MOON              -1.270415              -0.050764              -0.040578
# ZET               -1.247276               0.336663               0.008420
# SXC               -1.270415              -0.050764              -0.040578
# QTL               -1.270415              -0.050764              -0.040578
# ENRG               0.862548              -0.851033               0.022520
# QRK               -0.551985               0.231609               0.015286
# RIC               -1.074074               0.294900               0.050351
# DGC               -1.270415              -0.050764              -0.040578
# BTB                0.862548              -0.851033               0.022520
# CAT               -1.270415              -0.050764              -0.040578
#
#           CoinName  Class
# 42         42 Coin      0
# 404        404Coin      0
# 1337     EliteCoin      0
# BTCD   BitcoinDark      0
# XPY        PayCoin      0
# PRC    ProsperCoin      2
# KOBO      KoboCoin      0
# ARG       Argentum      2
# BLU       BlueCoin      0
# XMY     MyriadCoin      2
# MOON      MoonCoin      2
# ZET       ZetaCoin      2
# SXC        SexCoin      2
# QTL        Quatloo      2
# ENRG    EnergyCoin      0
# QRK      QuarkCoin      2
# RIC        Riecoin      2
# DGC   Digitalcoin       2
# BTB         BitBar      0
# CAT        Catcoin      2

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(
    df_cluster_pca,
    x="principal component 1",
    y="principal component 2",
    z="principal component 3",
    color="class",
    symbol="class",
    width=800,
)
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-407b7af8d396> in <module>
#       7     color="class",
#       8     symbol="class",
# ----> 9     width=800,
#      10 )
#      11 fig.update_layout(legend=dict(x=0, y=1))
#
# /opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/plotly/express/_chart_types.py in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
#     672     symbol mark in 3D space.
#     673     """
# --> 674     return make_figure(args=locals(), constructor=go.Scatter3d)
#     675
#     676
#
# /opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1829     apply_default_cascade(args)
#    1830
# -> 1831     args = build_dataframe(args, constructor)
#    1832     if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1833         args = process_dataframe_hierarchy(args)
#
# /opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1362
#    1363     df_output, wide_id_vars = process_args_into_dataframe(
# -> 1364         args, wide_mode, var_name, value_name
#    1365     )
#    1366
#
# /opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1164                         if argument == "index":
#    1165                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1166                         raise ValueError(err_msg)
#    1167                 elif length and len(df_input[argument]) != length:
#    1168                     raise ValueError(
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['PC 1', 'PC 2', 'PC 3', 'class'] but received: principal component 1

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

columns = ['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 'TotalCoinsMined', 'Class']
df_clustered.hvplot.table(columns,colormap="viridis")
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinSupply,TotalCoinsMined,Class]

# %%
# Print the total number of tradable cryptocurrencies
print("The number of tradable cryptocurrencies is") 
df_clustered["CoinName"].count()
# Out:
# The number of tradable cryptocurrencies is
# 539

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
df_clustered['TotalCoinsMined'] = df_clustered['TotalCoinsMined'].astype(float) / 100000000

df_clustered['TotalCoinSupply'] = df_clustered['TotalCoinSupply'].astype(float) / 100000000

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"

df_clustered.hvplot(
    kind="scatter", 
    x="TotalCoinsMined", 
    y="TotalCoinSupply", 
    c='Class',
    rot= 90, 
    colormap="inferno", 
    hover_cols=['CoinName']
)
# Out:
# :Scatter   [TotalCoinsMined]   (TotalCoinSupply,Class,CoinName)
